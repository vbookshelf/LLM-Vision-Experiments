# %%
import threading
import time

# Global flag to stop threads
stop_threads = False

# Function to print numbers
def number_printer():
    count = 0
    while not stop_threads:
        print(f"Number: {count}")
        count += 1
        time.sleep(1)  # Pause for 1 second

# Function to capture user input
def user_input():
    global stop_threads
    while not stop_threads:
        user_text = input("Enter some text (or 'exit' to stop): ")
        if user_text.lower() == 'exit':
            stop_threads = True
        else:
            print(f"You entered: {user_text}")

# Create and start threads
number_thread = threading.Thread(target=number_printer)
input_thread = threading.Thread(target=user_input)

number_thread.start()
input_thread.start()

# Wait for both threads to finish
number_thread.join()
input_thread.join()

print("Program has ended.")
# Out:
# Number: 0
# Number: 1
# Number: 2
# Number: 3
# Number: 4
# Number: 5
# Number: 6
# Number: 7
# Number: 8
# Number: 9
# Number: 10
# Enter some text (or 'exit' to stop):  hello
# You entered: hello
# Number: 11
# Number: 12
# Number: 13
# Number: 14
# Number: 15
# Number: 16
# Number: 17
# Number: 18
# Enter some text (or 'exit' to stop):  exit
# Number: 19
# Program has ended.
